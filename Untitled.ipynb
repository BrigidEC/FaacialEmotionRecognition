# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x0000023ADB6D2310>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed')': /packages/1e/5c/2187e20e7e8451655d4ba2ccb0d4638673a9ccc5f5fe80f8f188808a92f6/opencv_python-4.4.0.44-cp38-cp38-win_amd64.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x0000023ADB6D2460>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed')': /packages/1e/5c/2187e20e7e8451655d4ba2ccb0d4638673a9ccc5f5fe80f8f188808a92f6/opencv_python-4.4.0.44-cp38-cp38-win_amd64.whl
# ...

# %%
conda install opencv
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - opencv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.9.0                |           py38_0         2.9 MB
#     libopencv-4.0.1            |       hbb9e17c_0        28.6 MB
#     opencv-4.0.1               |   py38h2a7c758_0          22 KB
#     py-opencv-4.0.1            |   py38he44ac1e_0         1.5 MB
#     ------------------------------------------------------------
#                                            Total:        33.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   libopencv          pkgs/main/win-64::libopencv-4.0.1-hbb9e17c_0
#   opencv             pkgs/main/win-64::opencv-4.0.1-py38h2a7c758_0
#   py-opencv          pkgs/main/win-64::py-opencv-4.0.1-py38he44ac1e_0
#
# ...

# %%
pip install dlib
# Out:
# ...
#   Created wheel for dlib: filename=dlib-19.21.0-cp38-cp38-win_amd64.whl size=2973018 sha256=0b7775cda6bdef3deeb2eec2e845ddeac7359fa4f8d5608d6b1207a764025382
#   Stored in directory: c:\users\bechi\appdata\local\pip\cache\wheels\3a\4e\b6\77346839e430150a62d9b46bf7e0a37181fe01fd07d5d452a7
# Successfully built dlib
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install face_recognition
# Out:
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566176 sha256=14a16ec262480aa6cf1d00ee283721226f96b206b7f02118763f79f5d2e7f3ca
#   Stored in directory: c:\users\bechi\appdata\local\pip\cache\wheels\b4\4b\8f\751e99d45f089bdf366a7d3e5066db3c2b84a62e4377f534d7
# Successfully built face-recognition-models
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, shutil, sys, time, re, glob, csv, random
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import pandas as pd
import dlib

# %%
#define emotion classes
categories = ['Neutral','Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise']

# %%
# face detector
detector = dlib.get_frontal_face_detector()

# Facial landmarks detector
predictor = dlib.shape_predictor('files/Training_data_labels.npy')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-3138364dce3a> in <module>
#       3
#       4 # Facial landmarks detector
# ----> 5 predictor = dlib.shape_predictor('files/Training_data_labels.npy')
#
# RuntimeError: Unexpected version found while deserializing dlib::shape_predictor.
